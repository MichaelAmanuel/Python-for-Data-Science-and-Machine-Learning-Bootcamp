# %%
import  plotly.graph_objs as go
from plotly.offline import init_notebook_mode, iplot
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.24.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
import pandas as pd
init_notebook_mode(connected=True)
import plotly.io as pio
pio.renderers.default = 'colab'
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.24.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df = pd.read_csv('/content/2014_World_Power_Consumption')

# %%
df.head()
# Out:
#          Country  Power Consumption KWH                        Text
# 0          China           5.523000e+12     China 5,523,000,000,000
# 1  United States           3.832000e+12    United 3,832,000,000,000
# 2       European           2.771000e+12  European 2,771,000,000,000
# 3         Russia           1.065000e+12    Russia 1,065,000,000,000
# 4          Japan           9.210000e+11       Japan 921,000,000,000

# %%
data = dict(
            type='choropleth',
            locations=df['Country'],
            locationmode= 'country names',
            colorscale = 'Viridis',
            reversescale = True,
            z = df['Power Consumption KWH'],
            text=df['Country'],
            colorbar=dict(title='Power Consumption')
            )

layout = dict( title='2014_World_Power_Consumption',
              geo=dict(showframe=False, projection_type='mercator')
              )

choromap = go.Figure(data=[data], layout=layout)

# %%
iplot(choromap, validate=False)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
usdf = pd.read_csv('/content/2012_Election_Data')

# %%
usdf.head()
# Out:
#    Year  ICPSR State Code  Alphanumeric State Code       State  \
# 0  2012                41                        1     Alabama
# 1  2012                81                        2      Alaska
# 2  2012                61                        3     Arizona
# 3  2012                42                        4    Arkansas
# 4  2012                71                        5  California
#
#   VEP Total Ballots Counted VEP Highest Office VAP Highest Office  \
# 0                       NaN              58.6%              56.0%
# 1                     58.9%              58.7%              55.3%
# 2                     53.0%              52.6%              46.5%
# 3                     51.1%              50.7%              47.7%
# 4                     55.7%              55.1%              45.1%
#
#   Total Ballots Counted Highest Office Voting-Eligible Population (VEP)  \
# 0                   NaN      2,074,338                        3,539,217
# ...

# %%
# data1 = dict(type='chropleth',
#             colorscale = 'Viridis',
#             reversescale = True,
#             locations = usdf['State Abv'],
#             z = usdf['Voting-Age Population (VAP)'],
#             locationmode= 'USA-states',
#             text = usdf['State'],
#             colorbar=dict(title='Voting-Age Population (VAP)')
#             )

# layout1 = dict(title = '2012 Election Data',
#               geo = dict(scope='usa', showlakes=True, lakecolor='rgb(85,173,244)'))

# choromap2 = go.Figure(data = [data1], layout= layout1)

data1 = dict(
            type='choropleth',
            colorscale='Viridis',
            reversescale=True,
            locations=usdf['State Abv'],
            z=usdf['Voting-Age Population (VAP)'],
            locationmode='USA-states',
            text=usdf['State'],
            colorbar=dict(title='Voting-Age Population (VAP)')
        )

layout1 = dict(
              title='2012 Election Data',
              geo=dict(scope='usa', showlakes=True, lakecolor='rgb(85,173,244)')
          )

choromap2 = go.Figure(data=[data1], layout=layout1)

# %%
iplot(choromap2)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
