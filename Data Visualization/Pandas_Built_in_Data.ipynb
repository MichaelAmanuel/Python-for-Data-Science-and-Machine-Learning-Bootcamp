# %%
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path = '/content/df1'

# %%
df1 = pd.read_csv(path, index_col=0)

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2 = pd.read_csv('/content/df2')

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
# @title c

from matplotlib import pyplot as plt
df2['c'].plot(kind='line', figsize=(8, 4), title='c')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
df1['A'].hist(bins=30, edgecolor='black')
# Out:
# <Axes: >

# %%
plt.hist(x= 'A', data=df1, bins=30, edgecolor='black')
# Out:
# (array([  1.,   0.,   0.,   1.,   4.,   8.,   9.,  11.,  15.,  30.,  52.,
#          51.,  83.,  91.,  97.,  97., 108.,  74.,  71.,  61.,  41.,  41.,
#          23.,  16.,   9.,   2.,   1.,   2.,   0.,   1.]),
#  array([-3.69320113, -3.45635322, -3.21950531, -2.98265739, -2.74580948,
#         -2.50896157, -2.27211365, -2.03526574, -1.79841783, -1.56156991,
#         -1.324722  , -1.08787409, -0.85102617, -0.61417826, -0.37733035,
#         -0.14048243,  0.09636548,  0.33321339,  0.57006131,  0.80690922,
#          1.04375713,  1.28060505,  1.51745296,  1.75430087,  1.99114879,
#          2.2279967 ,  2.46484461,  2.70169253,  2.93854044,  3.17538835,
#          3.41223627]),
#  <BarContainer object of 30 artists>)

# %%
df1['A'].plot(kind='hist', bins=30, edgecolor='black')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1['A'].plot.hist(bins=30,edgecolor='black')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df2.plot(kind='area', alpha=.4)
# Out:
# <Axes: >

# %%
df2.plot.bar(stacked=True)
# Out:
# <Axes: >

# %%
df1['A'].plot.hist(bins=50,edgecolor='black')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1.plot.line(y='B', figsize=(12, 3),lw=1)
# Out:
# <Axes: >

# %%
df1.plot.scatter(x='A', y='B', c= 'C', cmap='coolwarm')
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
df1.plot.hexbin(x='A', y='B')
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
df1.plot.scatter(x='A', y='B', s=df1['C']*50, cmap='coolwarm')
# Out:
# /usr/local/lib/python3.10/dist-packages/matplotlib/collections.py:963: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_matplotlib/core.py:1259: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# <Axes: xlabel='A', ylabel='B'>

# %%
df2.plot.box()
# Out:
# <Axes: >

# %%
df = pd.DataFrame(np.random.rand(1000, 2), columns=['a', 'b'])

# %%
df.head()
# Out:
#           a         b
# 0  0.062647  0.920207
# 1  0.932715  0.690130
# 2  0.451462  0.313231
# 3  0.944714  0.979603
# 4  0.449805  0.847946

# %%
df.plot.hexbin(x='a', y='b',gridsize=25, cmap='coolwarm')
# Out:
# <Axes: xlabel='a', ylabel='b'>

# %%
df2['a'].plot.kde()
# Out:
# <Axes: ylabel='Density'>

# %%
df['a'].plot.density()
# Out:
# <Axes: ylabel='Density'>

# %%
df.plot.density()
# Out:
# <Axes: ylabel='Density'>
